# %%
import pandas as pd
import numpy as np
import algos.shallow_nn as shallow_nn
import algos.logistic_regression as logistic_regression
import algos.deep_nn as deep_nn
import pylab as plt

# %%
data = pd.read_csv("datasets/heart/heart.csv")
data = data.sample(frac=1).reset_index(drop=True)

data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   68    1   0       144   193    1        1      141      0      3.4      1
# 1   48    1   0       130   256    1        0      150      1      0.0      2
# 2   59    1   0       110   239    0        0      142      1      1.2      1
# 3   54    1   0       122   286    0        0      116      1      3.2      1
# 4   52    0   2       136   196    0        0      169      0      0.1      1
#
#    ca  thal  target
# 0   2     3       0
# 1   2     3       0
# 2   1     3       0
# 3   2     2       0
# 4   0     2       1

# %%
plt.scatter(data[data.target == 1]["chol"], data[data.target == 1]["age"], marker="o")

plt.scatter(data[data.target == 0]["chol"], data[data.target == 0]["age"], marker="x", color="red")

# %%
y = data["target"]

features = ["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal"]
X = pd.get_dummies(data[features])

y = np.array([y]).T
X = np.array(X)

X_train = X[:(int(len(X)*0.75)), :].T
X_val = X[(int(len(X)*0.75)):, :].T
y_train = y[:(int(len(X)*0.75)), :].T
y_val = y[(int(len(X)*0.75)):, :].T

# %%
y_train.shape
# Out:
# (1, 227)

# %%
snn_model = shallow_nn.model(X_train, y_train, X_val, y_val, n_h = 5, num_iterations=5000, learning_rate=0.0015, print_cost=True)
# Out:
# Cost after iteration 0: 0.693147
# Cost after iteration 500: 0.565931
# Cost after iteration 1000: 0.477696
# Cost after iteration 1500: 0.415327
# Cost after iteration 2000: 0.370208
# Cost after iteration 2500: 0.336793
# Cost after iteration 3000: 0.311499
# Cost after iteration 3500: 0.291969
# Cost after iteration 4000: 0.276623
# Cost after iteration 4500: 0.264377
# Cost after iteration 4999: 0.254489
# train accuracy: 95.07474013766566 %
# test accuracy: 91.67821668376743 %

# %%
layer_dims = [13, 10, 7, 5, 1]

nn_model = deep_nn.model(X_train, y_train, X_val, y_val, layers_dims=layer_dims, learning_rate=0.1, print_cost = True)
# Out:
# Cost after iteration 0: 0.6893176362633396
# Cost after iteration 300: 0.19627094729936484
# Cost after iteration 600: 0.19627011366495034
# Cost after iteration 900: 0.19626932336076897
# Cost after iteration 1200: 0.1962685263420583
# Cost after iteration 1500: 0.19626772240977203
# Cost after iteration 1800: 0.19626691140248684
# Cost after iteration 2100: 0.19626609374389584
# Cost after iteration 2400: 0.1962652687829363
# Cost after iteration 2700: 0.19626443621127182
# Cost after iteration 2999: 0.19626359864881093
# train accuracy: 95.07474013766566 %
# test accuracy: 91.67821668376743 %
